# %%
import requests
url = "https://ghoapi.azureedge.net/api/NCD_BMI_30C"
result = requests.get(url)
data = result.json()

# %%
data.keys()
# Out:
# dict_keys(['@odata.context', 'value'])

# %%
import pandas as pd
df1 = pd.DataFrame(data['value'])
df1.head()
# Out:
#         Id IndicatorCode SpatialDimType SpatialDim TimeDimType  \
# 0  8734302   NCD_BMI_30C        COUNTRY        SOM        YEAR
# 1  8734335   NCD_BMI_30C        COUNTRY        TCD        YEAR
# 2  8734867   NCD_BMI_30C        COUNTRY        TJK        YEAR
# 3  8736705   NCD_BMI_30C        COUNTRY        IRL        YEAR
# 4  8736802   NCD_BMI_30C        COUNTRY        SAU        YEAR
#
#   ParentLocationCode         ParentLocation Dim1Type      Dim1  TimeDim  ...  \
# 0                EMR  Eastern Mediterranean      SEX  SEX_BTSX     2007  ...
# 1                AFR                 Africa      SEX  SEX_FMLE     2017  ...
# 2                EUR                 Europe      SEX   SEX_MLE     2008  ...
# 3                EUR                 Europe      SEX  SEX_BTSX     1996  ...
# 4                EMR  Eastern Mediterranean      SEX  SEX_BTSX     2018  ...
#
#   DataSourceDim             Value NumericValue       Low      High Comments  \
# 0          None     6.6 [4.3-9.5]      6.59456   4.28883   9.45813     None
# 1          None     4.2 [3.1-5.4]      4.17558   3.14044   5.40993     None
# 2          None   10.0 [7.0-13.5]      9.99909   7.03050  13.51542     None
# 3          None  16.8 [15.1-18.7]     16.82392  15.06897  18.69106     None
# 4          None  38.3 [34.9-41.9]     38.30225  34.92298  41.87444     None
#
#                             Date  TimeDimensionValue  \
# 0  2024-02-29T16:06:41.017+01:00                2007
# 1  2024-02-29T16:06:41.017+01:00                2017
# 2  2024-02-29T16:06:41.017+01:00                2008
# 3  2024-02-29T16:06:41.017+01:00                1996
# 4  2024-02-29T16:06:41.017+01:00                2018
#
#           TimeDimensionBegin           TimeDimensionEnd
# 0  2007-01-01T00:00:00+01:00  2007-12-31T00:00:00+01:00
# 1  2017-01-01T00:00:00+01:00  2017-12-31T00:00:00+01:00
# 2  2008-01-01T00:00:00+01:00  2008-12-31T00:00:00+01:00
# 3  1996-01-01T00:00:00+01:00  1996-12-31T00:00:00+01:00
# 4  2018-01-01T00:00:00+01:00  2018-12-31T00:00:00+01:00
#
# [5 rows x 25 columns]

# %%
df1['age_group'] = "Adult"

# %%
df1.head()
# Out:
#         Id IndicatorCode SpatialDimType SpatialDim TimeDimType  \
# 0  8734302   NCD_BMI_30C        COUNTRY        SOM        YEAR
# 1  8734335   NCD_BMI_30C        COUNTRY        TCD        YEAR
# 2  8734867   NCD_BMI_30C        COUNTRY        TJK        YEAR
# 3  8736705   NCD_BMI_30C        COUNTRY        IRL        YEAR
# 4  8736802   NCD_BMI_30C        COUNTRY        SAU        YEAR
#
#   ParentLocationCode         ParentLocation Dim1Type      Dim1  TimeDim  ...  \
# 0                EMR  Eastern Mediterranean      SEX  SEX_BTSX     2007  ...
# 1                AFR                 Africa      SEX  SEX_FMLE     2017  ...
# 2                EUR                 Europe      SEX   SEX_MLE     2008  ...
# 3                EUR                 Europe      SEX  SEX_BTSX     1996  ...
# 4                EMR  Eastern Mediterranean      SEX  SEX_BTSX     2018  ...
#
#               Value NumericValue       Low      High Comments  \
# 0     6.6 [4.3-9.5]      6.59456   4.28883   9.45813     None
# 1     4.2 [3.1-5.4]      4.17558   3.14044   5.40993     None
# 2   10.0 [7.0-13.5]      9.99909   7.03050  13.51542     None
# 3  16.8 [15.1-18.7]     16.82392  15.06897  18.69106     None
# 4  38.3 [34.9-41.9]     38.30225  34.92298  41.87444     None
#
#                             Date TimeDimensionValue  \
# 0  2024-02-29T16:06:41.017+01:00               2007
# 1  2024-02-29T16:06:41.017+01:00               2017
# 2  2024-02-29T16:06:41.017+01:00               2008
# 3  2024-02-29T16:06:41.017+01:00               1996
# 4  2024-02-29T16:06:41.017+01:00               2018
#
#           TimeDimensionBegin           TimeDimensionEnd  age_group
# 0  2007-01-01T00:00:00+01:00  2007-12-31T00:00:00+01:00      Adult
# 1  2017-01-01T00:00:00+01:00  2017-12-31T00:00:00+01:00      Adult
# 2  2008-01-01T00:00:00+01:00  2008-12-31T00:00:00+01:00      Adult
# 3  1996-01-01T00:00:00+01:00  1996-12-31T00:00:00+01:00      Adult
# 4  2018-01-01T00:00:00+01:00  2018-12-31T00:00:00+01:00      Adult
#
# [5 rows x 26 columns]

# %%
import requests
url = "https://ghoapi.azureedge.net/api/NCD_BMI_PLUS2C"
result = requests.get(url)
data = result.json()

# %%
data.keys()
# Out:
# dict_keys(['@odata.context', 'value'])

# %%
df2 = pd.DataFrame(data['value'])
df2.head()
# Out:
#         Id   IndicatorCode SpatialDimType SpatialDim ParentLocationCode  \
# 0  8733159  NCD_BMI_PLUS2C        COUNTRY        LBY                EMR
# 1  8733449  NCD_BMI_PLUS2C        COUNTRY        SLV                AMR
# 2  8733834  NCD_BMI_PLUS2C        COUNTRY        SLE                AFR
# 3  8734007  NCD_BMI_PLUS2C        COUNTRY        TZA                AFR
# 4  8734040  NCD_BMI_PLUS2C        COUNTRY        TKM                EUR
#
#   TimeDimType         ParentLocation Dim1Type  TimeDim      Dim1  ...  \
# 0        YEAR  Eastern Mediterranean      SEX     1994  SEX_FMLE  ...
# 1        YEAR               Americas      SEX     2004  SEX_BTSX  ...
# 2        YEAR                 Africa      SEX     2003   SEX_MLE  ...
# 3        YEAR                 Africa      SEX     1996  SEX_FMLE  ...
# 4        YEAR                 Europe      SEX     2019  SEX_FMLE  ...
#
#   DataSourceDim           Value NumericValue      Low      High Comments  \
# 0          None  5.5 [2.3-10.4]      5.46429  2.30169  10.36518     None
# 1          None  8.2 [5.5-11.9]      8.22886  5.47262  11.85564     None
# 2          None   0.6 [0.1-1.5]      0.57658  0.11616   1.53144     None
# 3          None   0.4 [0.1-1.0]      0.42591  0.13694   0.96034     None
# 4          None   2.1 [1.0-3.7]      2.08894  0.97927   3.65200     None
#
#                             Date  TimeDimensionValue  \
# 0  2024-02-29T16:06:41.017+01:00                1994
# 1  2024-02-29T16:06:41.017+01:00                2004
# 2  2024-02-29T16:06:41.017+01:00                2003
# 3  2024-02-29T16:06:41.017+01:00                1996
# 4  2024-02-29T16:06:41.017+01:00                2019
#
#           TimeDimensionBegin           TimeDimensionEnd
# 0  1994-01-01T00:00:00+01:00  1994-12-31T00:00:00+01:00
# 1  2004-01-01T00:00:00+01:00  2004-12-31T00:00:00+01:00
# 2  2003-01-01T00:00:00+01:00  2003-12-31T00:00:00+01:00
# 3  1996-01-01T00:00:00+01:00  1996-12-31T00:00:00+01:00
# 4  2019-01-01T00:00:00+01:00  2019-12-31T00:00:00+01:00
#
# [5 rows x 25 columns]

# %%
df2['age_group'] = "Child"

# %%
df2.head()
# Out:
#         Id   IndicatorCode SpatialDimType SpatialDim ParentLocationCode  \
# 0  8733159  NCD_BMI_PLUS2C        COUNTRY        LBY                EMR
# 1  8733449  NCD_BMI_PLUS2C        COUNTRY        SLV                AMR
# 2  8733834  NCD_BMI_PLUS2C        COUNTRY        SLE                AFR
# 3  8734007  NCD_BMI_PLUS2C        COUNTRY        TZA                AFR
# 4  8734040  NCD_BMI_PLUS2C        COUNTRY        TKM                EUR
#
#   TimeDimType         ParentLocation Dim1Type  TimeDim      Dim1  ...  \
# 0        YEAR  Eastern Mediterranean      SEX     1994  SEX_FMLE  ...
# 1        YEAR               Americas      SEX     2004  SEX_BTSX  ...
# 2        YEAR                 Africa      SEX     2003   SEX_MLE  ...
# 3        YEAR                 Africa      SEX     1996  SEX_FMLE  ...
# 4        YEAR                 Europe      SEX     2019  SEX_FMLE  ...
#
#             Value NumericValue      Low      High Comments  \
# 0  5.5 [2.3-10.4]      5.46429  2.30169  10.36518     None
# 1  8.2 [5.5-11.9]      8.22886  5.47262  11.85564     None
# 2   0.6 [0.1-1.5]      0.57658  0.11616   1.53144     None
# 3   0.4 [0.1-1.0]      0.42591  0.13694   0.96034     None
# 4   2.1 [1.0-3.7]      2.08894  0.97927   3.65200     None
#
#                             Date TimeDimensionValue  \
# 0  2024-02-29T16:06:41.017+01:00               1994
# 1  2024-02-29T16:06:41.017+01:00               2004
# 2  2024-02-29T16:06:41.017+01:00               2003
# 3  2024-02-29T16:06:41.017+01:00               1996
# 4  2024-02-29T16:06:41.017+01:00               2019
#
#           TimeDimensionBegin           TimeDimensionEnd  age_group
# 0  1994-01-01T00:00:00+01:00  1994-12-31T00:00:00+01:00      Child
# 1  2004-01-01T00:00:00+01:00  2004-12-31T00:00:00+01:00      Child
# 2  2003-01-01T00:00:00+01:00  2003-12-31T00:00:00+01:00      Child
# 3  1996-01-01T00:00:00+01:00  1996-12-31T00:00:00+01:00      Child
# 4  2019-01-01T00:00:00+01:00  2019-12-31T00:00:00+01:00      Child
#
# [5 rows x 26 columns]

# %%
df_obesity = pd.concat([df1, df2], ignore_index = True)
print(df_obesity)
# Out:
#             Id   IndicatorCode SpatialDimType SpatialDim TimeDimType  \
# 0      8734302     NCD_BMI_30C        COUNTRY        SOM        YEAR
# 1      8734335     NCD_BMI_30C        COUNTRY        TCD        YEAR
# 2      8734867     NCD_BMI_30C        COUNTRY        TJK        YEAR
# 3      8736705     NCD_BMI_30C        COUNTRY        IRL        YEAR
# 4      8736802     NCD_BMI_30C        COUNTRY        SAU        YEAR
# ...        ...             ...            ...        ...         ...
# 83155  8731361  NCD_BMI_PLUS2C        COUNTRY        GNB        YEAR
# 83156  8731482  NCD_BMI_PLUS2C        COUNTRY        USA        YEAR
# 83157  8731754  NCD_BMI_PLUS2C        COUNTRY        AFG        YEAR
# 83158  8731985  NCD_BMI_PLUS2C        COUNTRY        ZMB        YEAR
# 83159  8732014  NCD_BMI_PLUS2C        COUNTRY        MOZ        YEAR
#
#       ParentLocationCode         ParentLocation Dim1Type      Dim1  TimeDim  \
# 0                    EMR  Eastern Mediterranean      SEX  SEX_BTSX     2007
# 1                    AFR                 Africa      SEX  SEX_FMLE     2017
# 2                    EUR                 Europe      SEX   SEX_MLE     2008
# 3                    EUR                 Europe      SEX  SEX_BTSX     1996
# 4                    EMR  Eastern Mediterranean      SEX  SEX_BTSX     2018
# ...                  ...                    ...      ...       ...      ...
# 83155                AFR                 Africa      SEX  SEX_BTSX     2015
# 83156                AMR               Americas      SEX  SEX_FMLE     1994
# 83157                EMR  Eastern Mediterranean      SEX  SEX_FMLE     2005
# 83158                AFR                 Africa      SEX  SEX_BTSX     1990
# 83159                AFR                 Africa      SEX  SEX_FMLE     2020
#
#        ...             Value NumericValue       Low      High Comments  \
# 0      ...     6.6 [4.3-9.5]      6.59456   4.28883   9.45813     None
# 1      ...     4.2 [3.1-5.4]      4.17558   3.14044   5.40993     None
# 2      ...   10.0 [7.0-13.5]      9.99909   7.03050  13.51542     None
# 3      ...  16.8 [15.1-18.7]     16.82392  15.06897  18.69106     None
# 4      ...  38.3 [34.9-41.9]     38.30225  34.92298  41.87444     None
# ...    ...               ...          ...       ...       ...      ...
# 83155  ...     3.7 [1.0-8.8]      3.66909   0.98686   8.84390     None
# 83156  ...  12.0 [10.3-13.9]     12.01837  10.25813  13.88898     None
# 83157  ...     2.5 [0.7-6.0]      2.53594   0.74616   5.95565     None
# 83158  ...     0.5 [0.1-1.4]      0.47718   0.09477   1.44881     None
# 83159  ...     1.6 [0.6-3.2]      1.63023   0.60048   3.21662     None
#
#                                 Date TimeDimensionValue  \
# 0      2024-02-29T16:06:41.017+01:00               2007
# 1      2024-02-29T16:06:41.017+01:00               2017
# 2      2024-02-29T16:06:41.017+01:00               2008
# 3      2024-02-29T16:06:41.017+01:00               1996
# 4      2024-02-29T16:06:41.017+01:00               2018
# ...                              ...                ...
# 83155  2024-02-29T16:06:41.017+01:00               2015
# 83156  2024-02-29T16:06:41.017+01:00               1994
# 83157  2024-02-29T16:06:41.017+01:00               2005
# 83158  2024-02-29T16:06:41.017+01:00               1990
# 83159  2024-02-29T16:06:41.017+01:00               2020
#
#               TimeDimensionBegin           TimeDimensionEnd  age_group
# 0      2007-01-01T00:00:00+01:00  2007-12-31T00:00:00+01:00      Adult
# 1      2017-01-01T00:00:00+01:00  2017-12-31T00:00:00+01:00      Adult
# 2      2008-01-01T00:00:00+01:00  2008-12-31T00:00:00+01:00      Adult
# 3      1996-01-01T00:00:00+01:00  1996-12-31T00:00:00+01:00      Adult
# 4      2018-01-01T00:00:00+01:00  2018-12-31T00:00:00+01:00      Adult
# ...                          ...                        ...        ...
# 83155  2015-01-01T00:00:00+01:00  2015-12-31T00:00:00+01:00      Child
# 83156  1994-01-01T00:00:00+01:00  1994-12-31T00:00:00+01:00      Child
# 83157  2005-01-01T00:00:00+01:00  2005-12-31T00:00:00+01:00      Child
# 83158  1990-01-01T00:00:00+01:00  1990-12-31T00:00:00+01:00      Child
# 83159  2020-01-01T00:00:00+01:00  2020-12-31T00:00:00+01:00      Child
#
# [83160 rows x 26 columns]

# %%
import requests
url = "https://ghoapi.azureedge.net/api/NCD_BMI_18C"
result = requests.get(url)
data = result.json()

# %%
data.keys()
# Out:
# dict_keys(['@odata.context', 'value'])

# %%
df3 = pd.DataFrame(data['value'])
df3.head()
# Out:
#         Id IndicatorCode SpatialDimType SpatialDim TimeDimType  \
# 0  8733094   NCD_BMI_18C        COUNTRY        NOR        YEAR
# 1  8734703   NCD_BMI_18C        COUNTRY        FIN        YEAR
# 2  8734839   NCD_BMI_18C        COUNTRY        ERI        YEAR
# 3  8735505   NCD_BMI_18C        COUNTRY        PRY        YEAR
# 4  8736665   NCD_BMI_18C        COUNTRY        YEM        YEAR
#
#   ParentLocationCode         ParentLocation Dim1Type  TimeDim      Dim1  ...  \
# 0                EUR                 Europe      SEX     2006  SEX_BTSX  ...
# 1                EUR                 Europe      SEX     1990  SEX_FMLE  ...
# 2                AFR                 Africa      SEX     2010   SEX_MLE  ...
# 3                AMR               Americas      SEX     2017   SEX_MLE  ...
# 4                EMR  Eastern Mediterranean      SEX     2014   SEX_MLE  ...
#
#   DataSourceDim             Value NumericValue       Low      High Comments  \
# 0          None     1.3 [1.0-1.7]      1.28019   0.96473   1.66373     None
# 1          None     2.6 [2.0-3.2]      2.59247   2.03309   3.24354     None
# 2          None  32.2 [27.0-37.4]     32.16327  26.96123  37.38672     None
# 3          None     2.6 [1.1-4.6]      2.55050   1.10349   4.62184     None
# 4          None   11.8 [8.0-16.0]     11.76163   7.98273  15.97617     None
#
#                             Date  TimeDimensionValue  \
# 0  2024-02-29T16:06:41.017+01:00                2006
# 1  2024-02-29T16:06:41.017+01:00                1990
# 2  2024-02-29T16:06:41.017+01:00                2010
# 3  2024-02-29T16:06:41.017+01:00                2017
# 4  2024-02-29T16:06:41.017+01:00                2014
#
#           TimeDimensionBegin           TimeDimensionEnd
# 0  2006-01-01T00:00:00+01:00  2006-12-31T00:00:00+01:00
# 1  1990-01-01T00:00:00+01:00  1990-12-31T00:00:00+01:00
# 2  2010-01-01T00:00:00+01:00  2010-12-31T00:00:00+01:00
# 3  2017-01-01T00:00:00+01:00  2017-12-31T00:00:00+01:00
# 4  2014-01-01T00:00:00+01:00  2014-12-31T00:00:00+01:00
#
# [5 rows x 25 columns]

# %%
df3['age_group'] = "Adult"

# %%
df3.head()
# Out:
#         Id IndicatorCode SpatialDimType SpatialDim TimeDimType  \
# 0  8733094   NCD_BMI_18C        COUNTRY        NOR        YEAR
# 1  8734703   NCD_BMI_18C        COUNTRY        FIN        YEAR
# 2  8734839   NCD_BMI_18C        COUNTRY        ERI        YEAR
# 3  8735505   NCD_BMI_18C        COUNTRY        PRY        YEAR
# 4  8736665   NCD_BMI_18C        COUNTRY        YEM        YEAR
#
#   ParentLocationCode         ParentLocation Dim1Type  TimeDim      Dim1  ...  \
# 0                EUR                 Europe      SEX     2006  SEX_BTSX  ...
# 1                EUR                 Europe      SEX     1990  SEX_FMLE  ...
# 2                AFR                 Africa      SEX     2010   SEX_MLE  ...
# 3                AMR               Americas      SEX     2017   SEX_MLE  ...
# 4                EMR  Eastern Mediterranean      SEX     2014   SEX_MLE  ...
#
#               Value NumericValue       Low      High Comments  \
# 0     1.3 [1.0-1.7]      1.28019   0.96473   1.66373     None
# 1     2.6 [2.0-3.2]      2.59247   2.03309   3.24354     None
# 2  32.2 [27.0-37.4]     32.16327  26.96123  37.38672     None
# 3     2.6 [1.1-4.6]      2.55050   1.10349   4.62184     None
# 4   11.8 [8.0-16.0]     11.76163   7.98273  15.97617     None
#
#                             Date TimeDimensionValue  \
# 0  2024-02-29T16:06:41.017+01:00               2006
# 1  2024-02-29T16:06:41.017+01:00               1990
# 2  2024-02-29T16:06:41.017+01:00               2010
# 3  2024-02-29T16:06:41.017+01:00               2017
# 4  2024-02-29T16:06:41.017+01:00               2014
#
#           TimeDimensionBegin           TimeDimensionEnd  age_group
# 0  2006-01-01T00:00:00+01:00  2006-12-31T00:00:00+01:00      Adult
# 1  1990-01-01T00:00:00+01:00  1990-12-31T00:00:00+01:00      Adult
# 2  2010-01-01T00:00:00+01:00  2010-12-31T00:00:00+01:00      Adult
# 3  2017-01-01T00:00:00+01:00  2017-12-31T00:00:00+01:00      Adult
# 4  2014-01-01T00:00:00+01:00  2014-12-31T00:00:00+01:00      Adult
#
# [5 rows x 26 columns]

# %%
import requests
url = "https://ghoapi.azureedge.net/api/NCD_BMI_MINUS2C"
result = requests.get(url)
data = result.json()

# %%
data.keys()
# Out:
# dict_keys(['@odata.context', 'value'])

# %%
df4 = pd.DataFrame(data['value'])
df4.head()
# Out:
#         Id    IndicatorCode SpatialDimType SpatialDim TimeDimType  \
# 0  8733231  NCD_BMI_MINUS2C        COUNTRY        LSO        YEAR
# 1  8733303  NCD_BMI_MINUS2C        COUNTRY        ARE        YEAR
# 2  8733307  NCD_BMI_MINUS2C        COUNTRY        GNQ        YEAR
# 3  8733377  NCD_BMI_MINUS2C        COUNTRY        PRT        YEAR
# 4  8733438  NCD_BMI_MINUS2C        COUNTRY        QAT        YEAR
#
#   ParentLocationCode         ParentLocation Dim1Type  TimeDim      Dim1  ...  \
# 0                AFR                 Africa      SEX     2007   SEX_MLE  ...
# 1                EMR  Eastern Mediterranean      SEX     2021   SEX_MLE  ...
# 2                AFR                 Africa      SEX     1998  SEX_FMLE  ...
# 3                EUR                 Europe      SEX     2019   SEX_MLE  ...
# 4                EMR  Eastern Mediterranean      SEX     1997  SEX_BTSX  ...
#
#   DataSourceDim           Value NumericValue      Low      High Comments  \
# 0          None  5.8 [1.9-11.9]      5.81177  1.90304  11.87054     None
# 1          None   4.6 [2.3-7.8]      4.57194  2.32892   7.76559     None
# 2          None  7.5 [2.2-16.5]      7.48935  2.17801  16.45536     None
# 3          None   2.5 [1.6-3.7]      2.50803  1.59297   3.66545     None
# 4          None   6.2 [3.6-9.5]      6.16969  3.56932   9.46996     None
#
#                             Date  TimeDimensionValue  \
# 0  2024-02-29T16:06:41.017+01:00                2007
# 1  2024-02-29T16:06:41.017+01:00                2021
# 2  2024-02-29T16:06:41.017+01:00                1998
# 3  2024-02-29T16:06:41.017+01:00                2019
# 4  2024-02-29T16:06:41.017+01:00                1997
#
#           TimeDimensionBegin           TimeDimensionEnd
# 0  2007-01-01T00:00:00+01:00  2007-12-31T00:00:00+01:00
# 1  2021-01-01T00:00:00+01:00  2021-12-31T00:00:00+01:00
# 2  1998-01-01T00:00:00+01:00  1998-12-31T00:00:00+01:00
# 3  2019-01-01T00:00:00+01:00  2019-12-31T00:00:00+01:00
# 4  1997-01-01T00:00:00+01:00  1997-12-31T00:00:00+01:00
#
# [5 rows x 25 columns]

# %%
df4['age_group'] = "Child"

# %%
df4.head()
# Out:
#         Id    IndicatorCode SpatialDimType SpatialDim TimeDimType  \
# 0  8733231  NCD_BMI_MINUS2C        COUNTRY        LSO        YEAR
# 1  8733303  NCD_BMI_MINUS2C        COUNTRY        ARE        YEAR
# 2  8733307  NCD_BMI_MINUS2C        COUNTRY        GNQ        YEAR
# 3  8733377  NCD_BMI_MINUS2C        COUNTRY        PRT        YEAR
# 4  8733438  NCD_BMI_MINUS2C        COUNTRY        QAT        YEAR
#
#   ParentLocationCode         ParentLocation Dim1Type  TimeDim      Dim1  ...  \
# 0                AFR                 Africa      SEX     2007   SEX_MLE  ...
# 1                EMR  Eastern Mediterranean      SEX     2021   SEX_MLE  ...
# 2                AFR                 Africa      SEX     1998  SEX_FMLE  ...
# 3                EUR                 Europe      SEX     2019   SEX_MLE  ...
# 4                EMR  Eastern Mediterranean      SEX     1997  SEX_BTSX  ...
#
#             Value NumericValue      Low      High Comments  \
# 0  5.8 [1.9-11.9]      5.81177  1.90304  11.87054     None
# 1   4.6 [2.3-7.8]      4.57194  2.32892   7.76559     None
# 2  7.5 [2.2-16.5]      7.48935  2.17801  16.45536     None
# 3   2.5 [1.6-3.7]      2.50803  1.59297   3.66545     None
# 4   6.2 [3.6-9.5]      6.16969  3.56932   9.46996     None
#
#                             Date TimeDimensionValue  \
# 0  2024-02-29T16:06:41.017+01:00               2007
# 1  2024-02-29T16:06:41.017+01:00               2021
# 2  2024-02-29T16:06:41.017+01:00               1998
# 3  2024-02-29T16:06:41.017+01:00               2019
# 4  2024-02-29T16:06:41.017+01:00               1997
#
#           TimeDimensionBegin           TimeDimensionEnd  age_group
# 0  2007-01-01T00:00:00+01:00  2007-12-31T00:00:00+01:00      Child
# 1  2021-01-01T00:00:00+01:00  2021-12-31T00:00:00+01:00      Child
# 2  1998-01-01T00:00:00+01:00  1998-12-31T00:00:00+01:00      Child
# 3  2019-01-01T00:00:00+01:00  2019-12-31T00:00:00+01:00      Child
# 4  1997-01-01T00:00:00+01:00  1997-12-31T00:00:00+01:00      Child
#
# [5 rows x 26 columns]

# %%
df_malnutrition = pd.concat([df3, df4], ignore_index = True)
print(df_malnutrition)
# Out:
#             Id    IndicatorCode SpatialDimType SpatialDim TimeDimType  \
# 0      8733094      NCD_BMI_18C        COUNTRY        NOR        YEAR
# 1      8734703      NCD_BMI_18C        COUNTRY        FIN        YEAR
# 2      8734839      NCD_BMI_18C        COUNTRY        ERI        YEAR
# 3      8735505      NCD_BMI_18C        COUNTRY        PRY        YEAR
# 4      8736665      NCD_BMI_18C        COUNTRY        YEM        YEAR
# ...        ...              ...            ...        ...         ...
# 83155  8731803  NCD_BMI_MINUS2C        COUNTRY        YEM        YEAR
# 83156  8731861  NCD_BMI_MINUS2C        COUNTRY        MWI        YEAR
# 83157  8731986  NCD_BMI_MINUS2C        COUNTRY        SLB        YEAR
# 83158  8731993  NCD_BMI_MINUS2C        COUNTRY        AUS        YEAR
# 83159  8732015  NCD_BMI_MINUS2C        COUNTRY        JOR        YEAR
#
#       ParentLocationCode         ParentLocation Dim1Type  TimeDim      Dim1  \
# 0                    EUR                 Europe      SEX     2006  SEX_BTSX
# 1                    EUR                 Europe      SEX     1990  SEX_FMLE
# 2                    AFR                 Africa      SEX     2010   SEX_MLE
# 3                    AMR               Americas      SEX     2017   SEX_MLE
# 4                    EMR  Eastern Mediterranean      SEX     2014   SEX_MLE
# ...                  ...                    ...      ...      ...       ...
# 83155                EMR  Eastern Mediterranean      SEX     2009  SEX_FMLE
# 83156                AFR                 Africa      SEX     2022  SEX_BTSX
# 83157                WPR        Western Pacific      SEX     1998  SEX_BTSX
# 83158                WPR        Western Pacific      SEX     2008  SEX_FMLE
# 83159                EMR  Eastern Mediterranean      SEX     2004  SEX_FMLE
#
#        ...             Value NumericValue       Low      High Comments  \
# 0      ...     1.3 [1.0-1.7]      1.28019   0.96473   1.66373     None
# 1      ...     2.6 [2.0-3.2]      2.59247   2.03309   3.24354     None
# 2      ...  32.2 [27.0-37.4]     32.16327  26.96123  37.38672     None
# 3      ...     2.6 [1.1-4.6]      2.55050   1.10349   4.62184     None
# 4      ...   11.8 [8.0-16.0]     11.76163   7.98273  15.97617     None
# ...    ...               ...          ...       ...       ...      ...
# 83155  ...   11.1 [9.1-13.1]     11.09520   9.12002  13.13477     None
# 83156  ...     4.0 [2.0-6.8]      4.00028   2.04478   6.83226     None
# 83157  ...     2.4 [0.8-4.8]      2.37262   0.84531   4.84894     None
# 83158  ...     1.1 [0.9-1.5]      1.14946   0.87681   1.46611     None
# 83159  ...     3.1 [1.7-4.9]      3.07074   1.72276   4.94191     None
#
#                                 Date TimeDimensionValue  \
# 0      2024-02-29T16:06:41.017+01:00               2006
# 1      2024-02-29T16:06:41.017+01:00               1990
# 2      2024-02-29T16:06:41.017+01:00               2010
# 3      2024-02-29T16:06:41.017+01:00               2017
# 4      2024-02-29T16:06:41.017+01:00               2014
# ...                              ...                ...
# 83155  2024-02-29T16:06:41.017+01:00               2009
# 83156  2024-02-29T16:06:41.017+01:00               2022
# 83157  2024-02-29T16:06:41.017+01:00               1998
# 83158  2024-02-29T16:06:41.017+01:00               2008
# 83159  2024-02-29T16:06:41.017+01:00               2004
#
#               TimeDimensionBegin           TimeDimensionEnd  age_group
# 0      2006-01-01T00:00:00+01:00  2006-12-31T00:00:00+01:00      Adult
# 1      1990-01-01T00:00:00+01:00  1990-12-31T00:00:00+01:00      Adult
# 2      2010-01-01T00:00:00+01:00  2010-12-31T00:00:00+01:00      Adult
# 3      2017-01-01T00:00:00+01:00  2017-12-31T00:00:00+01:00      Adult
# 4      2014-01-01T00:00:00+01:00  2014-12-31T00:00:00+01:00      Adult
# ...                          ...                        ...        ...
# 83155  2009-01-01T00:00:00+01:00  2009-12-31T00:00:00+01:00      Child
# 83156  2022-01-01T00:00:00+01:00  2022-12-31T00:00:00+01:00      Child
# 83157  1998-01-01T00:00:00+01:00  1998-12-31T00:00:00+01:00      Child
# 83158  2008-01-01T00:00:00+01:00  2008-12-31T00:00:00+01:00      Child
# 83159  2004-01-01T00:00:00+01:00  2004-12-31T00:00:00+01:00      Child
#
# [83160 rows x 26 columns]

# %%
df_obesity = df_obesity[(df_obesity['TimeDim'] >= 2012)  & (df_obesity['TimeDim'] <= 2022)]

# %%
print(df_obesity)
# Out:
#             Id   IndicatorCode SpatialDimType SpatialDim TimeDimType  \
# 1      8734335     NCD_BMI_30C        COUNTRY        TCD        YEAR
# 4      8736802     NCD_BMI_30C        COUNTRY        SAU        YEAR
# 5      8736997     NCD_BMI_30C        COUNTRY        CZE        YEAR
# 9      8740554     NCD_BMI_30C        COUNTRY        MWI        YEAR
# 13     8741877     NCD_BMI_30C        COUNTRY        GUY        YEAR
# ...        ...             ...            ...        ...         ...
# 83151  8730548  NCD_BMI_PLUS2C        COUNTRY        CHE        YEAR
# 83153  8730752  NCD_BMI_PLUS2C        COUNTRY        MMR        YEAR
# 83154  8731150  NCD_BMI_PLUS2C        COUNTRY        GAB        YEAR
# 83155  8731361  NCD_BMI_PLUS2C        COUNTRY        GNB        YEAR
# 83159  8732014  NCD_BMI_PLUS2C        COUNTRY        MOZ        YEAR
#
#       ParentLocationCode         ParentLocation Dim1Type      Dim1  TimeDim  \
# 1                    AFR                 Africa      SEX  SEX_FMLE     2017
# 4                    EMR  Eastern Mediterranean      SEX  SEX_BTSX     2018
# 5                    EUR                 Europe      SEX  SEX_BTSX     2022
# 9                    AFR                 Africa      SEX   SEX_MLE     2017
# 13                   AMR               Americas      SEX  SEX_FMLE     2022
# ...                  ...                    ...      ...       ...      ...
# 83151                EUR                 Europe      SEX  SEX_BTSX     2012
# 83153               SEAR        South-East Asia      SEX   SEX_MLE     2015
# 83154                AFR                 Africa      SEX  SEX_BTSX     2014
# 83155                AFR                 Africa      SEX  SEX_BTSX     2015
# 83159                AFR                 Africa      SEX  SEX_FMLE     2020
#
#        ...             Value NumericValue       Low      High Comments  \
# 1      ...     4.2 [3.1-5.4]      4.17558   3.14044   5.40993     None
# 4      ...  38.3 [34.9-41.9]     38.30225  34.92298  41.87444     None
# 5      ...  31.3 [28.3-34.4]     31.29533  28.31155  34.41646     None
# 9      ...     1.8 [1.2-2.4]      1.76076   1.22144   2.41332     None
# 13     ...  37.8 [31.7-44.2]     37.80555  31.74306  44.23656     None
# ...    ...               ...          ...       ...       ...      ...
# 83151  ...     5.7 [5.1-6.4]      5.73496   5.14733   6.37663     None
# 83153  ...    9.6 [2.5-21.1]      9.61965   2.47222  21.08884     None
# 83154  ...     3.2 [1.5-5.9]      3.19039   1.54235   5.90774     None
# 83155  ...     3.7 [1.0-8.8]      3.66909   0.98686   8.84390     None
# 83159  ...     1.6 [0.6-3.2]      1.63023   0.60048   3.21662     None
#
#                                 Date TimeDimensionValue  \
# 1      2024-02-29T16:06:41.017+01:00               2017
# 4      2024-02-29T16:06:41.017+01:00               2018
# 5      2024-02-29T16:06:41.017+01:00               2022
# 9      2024-02-29T16:06:41.017+01:00               2017
# 13     2024-02-29T16:06:41.017+01:00               2022
# ...                              ...                ...
# 83151  2024-02-29T16:06:41.017+01:00               2012
# 83153  2024-02-29T16:06:41.017+01:00               2015
# 83154  2024-02-29T16:06:41.017+01:00               2014
# 83155  2024-02-29T16:06:41.017+01:00               2015
# 83159  2024-02-29T16:06:41.017+01:00               2020
#
#               TimeDimensionBegin           TimeDimensionEnd  age_group
# 1      2017-01-01T00:00:00+01:00  2017-12-31T00:00:00+01:00      Adult
# 4      2018-01-01T00:00:00+01:00  2018-12-31T00:00:00+01:00      Adult
# 5      2022-01-01T00:00:00+01:00  2022-12-31T00:00:00+01:00      Adult
# 9      2017-01-01T00:00:00+01:00  2017-12-31T00:00:00+01:00      Adult
# 13     2022-01-01T00:00:00+01:00  2022-12-31T00:00:00+01:00      Adult
# ...                          ...                        ...        ...
# 83151  2012-01-01T00:00:00+01:00  2012-12-31T00:00:00+01:00      Child
# 83153  2015-01-01T00:00:00+01:00  2015-12-31T00:00:00+01:00      Child
# 83154  2014-01-01T00:00:00+01:00  2014-12-31T00:00:00+01:00      Child
# 83155  2015-01-01T00:00:00+01:00  2015-12-31T00:00:00+01:00      Child
# 83159  2020-01-01T00:00:00+01:00  2020-12-31T00:00:00+01:00      Child
#
# [27720 rows x 26 columns]

# %%
df_malnutrition = df_malnutrition[(df_malnutrition['TimeDim'] >= 2012) & (df_malnutrition['TimeDim'] <= 2022)]

# %%
print(df_malnutrition)
# Out:
#             Id    IndicatorCode SpatialDimType SpatialDim TimeDimType  \
# 3      8735505      NCD_BMI_18C        COUNTRY        PRY        YEAR
# 4      8736665      NCD_BMI_18C        COUNTRY        YEM        YEAR
# 5      8737128      NCD_BMI_18C        COUNTRY        PAK        YEAR
# 11     8739478      NCD_BMI_18C        COUNTRY        GNQ        YEAR
# 14     8743566      NCD_BMI_18C        COUNTRY        UZB        YEAR
# ...        ...              ...            ...        ...         ...
# 83147  8730733  NCD_BMI_MINUS2C        COUNTRY        SVK        YEAR
# 83149  8730845  NCD_BMI_MINUS2C        COUNTRY        SEN        YEAR
# 83152  8731738  NCD_BMI_MINUS2C        COUNTRY        DOM        YEAR
# 83153  8731758  NCD_BMI_MINUS2C        COUNTRY        TKL        YEAR
# 83156  8731861  NCD_BMI_MINUS2C        COUNTRY        MWI        YEAR
#
#       ParentLocationCode         ParentLocation Dim1Type  TimeDim      Dim1  \
# 3                    AMR               Americas      SEX     2017   SEX_MLE
# 4                    EMR  Eastern Mediterranean      SEX     2014   SEX_MLE
# 5                    EMR  Eastern Mediterranean      SEX     2015  SEX_FMLE
# 11                   AFR                 Africa      SEX     2016  SEX_BTSX
# 14                   EUR                 Europe      SEX     2013   SEX_MLE
# ...                  ...                    ...      ...      ...       ...
# 83147                EUR                 Europe      SEX     2019  SEX_BTSX
# 83149                AFR                 Africa      SEX     2013   SEX_MLE
# 83152                AMR               Americas      SEX     2012  SEX_FMLE
# 83153                WPR        Western Pacific      SEX     2016  SEX_BTSX
# 83156                AFR                 Africa      SEX     2022  SEX_BTSX
#
#        ...             Value NumericValue       Low      High Comments  \
# 3      ...     2.6 [1.1-4.6]      2.55050   1.10349   4.62184     None
# 4      ...   11.8 [8.0-16.0]     11.76163   7.98273  15.97617     None
# 5      ...  11.9 [10.4-13.4]     11.86974  10.41785  13.39566     None
# 11     ...    9.8 [4.6-16.7]      9.83577   4.62815  16.73667     None
# 14     ...     2.5 [1.7-3.6]      2.52340   1.68666   3.57636     None
# ...    ...               ...          ...       ...       ...      ...
# 83147  ...     3.3 [2.4-4.4]      3.30044   2.41504   4.39023     None
# 83149  ...  24.3 [18.8-29.9]     24.34631  18.84535  29.93256     None
# 83152  ...    4.9 [1.6-11.1]      4.93383   1.56834  11.06366     None
# 83153  ...     1.2 [0.2-3.6]      1.22150   0.22261   3.57992     None
# 83156  ...     4.0 [2.0-6.8]      4.00028   2.04478   6.83226     None
#
#                                 Date TimeDimensionValue  \
# 3      2024-02-29T16:06:41.017+01:00               2017
# 4      2024-02-29T16:06:41.017+01:00               2014
# 5      2024-02-29T16:06:41.017+01:00               2015
# 11     2024-02-29T16:06:41.017+01:00               2016
# 14     2024-02-29T16:06:41.017+01:00               2013
# ...                              ...                ...
# 83147  2024-02-29T16:06:41.017+01:00               2019
# 83149  2024-02-29T16:06:41.017+01:00               2013
# 83152  2024-02-29T16:06:41.017+01:00               2012
# 83153  2024-02-29T16:06:41.017+01:00               2016
# 83156  2024-02-29T16:06:41.017+01:00               2022
#
#               TimeDimensionBegin           TimeDimensionEnd  age_group
# 3      2017-01-01T00:00:00+01:00  2017-12-31T00:00:00+01:00      Adult
# 4      2014-01-01T00:00:00+01:00  2014-12-31T00:00:00+01:00      Adult
# 5      2015-01-01T00:00:00+01:00  2015-12-31T00:00:00+01:00      Adult
# 11     2016-01-01T00:00:00+01:00  2016-12-31T00:00:00+01:00      Adult
# 14     2013-01-01T00:00:00+01:00  2013-12-31T00:00:00+01:00      Adult
# ...                          ...                        ...        ...
# 83147  2019-01-01T00:00:00+01:00  2019-12-31T00:00:00+01:00      Child
# 83149  2013-01-01T00:00:00+01:00  2013-12-31T00:00:00+01:00      Child
# 83152  2012-01-01T00:00:00+01:00  2012-12-31T00:00:00+01:00      Child
# 83153  2016-01-01T00:00:00+01:00  2016-12-31T00:00:00+01:00      Child
# 83156  2022-01-01T00:00:00+01:00  2022-12-31T00:00:00+01:00      Child
#
# [27720 rows x 26 columns]

# %%
print(df_obesity.head())
# Out:
#          Id IndicatorCode SpatialDimType SpatialDim TimeDimType  \
# 1   8734335   NCD_BMI_30C        COUNTRY        TCD        YEAR
# 4   8736802   NCD_BMI_30C        COUNTRY        SAU        YEAR
# 5   8736997   NCD_BMI_30C        COUNTRY        CZE        YEAR
# 9   8740554   NCD_BMI_30C        COUNTRY        MWI        YEAR
# 13  8741877   NCD_BMI_30C        COUNTRY        GUY        YEAR
#
#    ParentLocationCode         ParentLocation Dim1Type      Dim1  TimeDim  ...  \
# 1                 AFR                 Africa      SEX  SEX_FMLE     2017  ...
# 4                 EMR  Eastern Mediterranean      SEX  SEX_BTSX     2018  ...
# 5                 EUR                 Europe      SEX  SEX_BTSX     2022  ...
# 9                 AFR                 Africa      SEX   SEX_MLE     2017  ...
# 13                AMR               Americas      SEX  SEX_FMLE     2022  ...
#
#                Value NumericValue       Low      High Comments  \
# 1      4.2 [3.1-5.4]      4.17558   3.14044   5.40993     None
# 4   38.3 [34.9-41.9]     38.30225  34.92298  41.87444     None
# 5   31.3 [28.3-34.4]     31.29533  28.31155  34.41646     None
# 9      1.8 [1.2-2.4]      1.76076   1.22144   2.41332     None
# 13  37.8 [31.7-44.2]     37.80555  31.74306  44.23656     None
#
#                              Date TimeDimensionValue  \
# 1   2024-02-29T16:06:41.017+01:00               2017
# 4   2024-02-29T16:06:41.017+01:00               2018
# 5   2024-02-29T16:06:41.017+01:00               2022
# 9   2024-02-29T16:06:41.017+01:00               2017
# 13  2024-02-29T16:06:41.017+01:00               2022
#
#            TimeDimensionBegin           TimeDimensionEnd  age_group
# 1   2017-01-01T00:00:00+01:00  2017-12-31T00:00:00+01:00      Adult
# 4   2018-01-01T00:00:00+01:00  2018-12-31T00:00:00+01:00      Adult
# 5   2022-01-01T00:00:00+01:00  2022-12-31T00:00:00+01:00      Adult
# 9   2017-01-01T00:00:00+01:00  2017-12-31T00:00:00+01:00      Adult
# 13  2022-01-01T00:00:00+01:00  2022-12-31T00:00:00+01:00      Adult
#
# [5 rows x 26 columns]

# %%
print(df_obesity['Dim1'])
# Out:
# 1        SEX_FMLE
# 4        SEX_BTSX
# 5        SEX_BTSX
# 9         SEX_MLE
# 13       SEX_FMLE
#            ...
# 83151    SEX_BTSX
# 83153     SEX_MLE
# 83154    SEX_BTSX
# 83155    SEX_BTSX
# 83159    SEX_FMLE
# Name: Dim1, Length: 27720, dtype: object

# %%
columns_to_keep = ['ParentLocation', 'Dim1', 'TimeDim', 'Low', 'High', 'NumericValue', 'SpatialDim', 'age_group']
df_obesity = df_obesity[columns_to_keep]

# %%
print(df_obesity.head())
# Out:
#            ParentLocation      Dim1  TimeDim       Low      High  \
# 1                  Africa  SEX_FMLE     2017   3.14044   5.40993
# 4   Eastern Mediterranean  SEX_BTSX     2018  34.92298  41.87444
# 5                  Europe  SEX_BTSX     2022  28.31155  34.41646
# 9                  Africa   SEX_MLE     2017   1.22144   2.41332
# 13               Americas  SEX_FMLE     2022  31.74306  44.23656
#
#     NumericValue SpatialDim age_group
# 1        4.17558        TCD     Adult
# 4       38.30225        SAU     Adult
# 5       31.29533        CZE     Adult
# 9        1.76076        MWI     Adult
# 13      37.80555        GUY     Adult

# %%
columns_to_keep = ['ParentLocation', 'Dim1', 'TimeDim', 'Low', 'High', 'NumericValue', 'SpatialDim', 'age_group']
df_malnutrition = df_malnutrition[columns_to_keep]

# %%
print(df_malnutrition.head())
# Out:
#            ParentLocation      Dim1  TimeDim       Low      High  \
# 3                Americas   SEX_MLE     2017   1.10349   4.62184
# 4   Eastern Mediterranean   SEX_MLE     2014   7.98273  15.97617
# 5   Eastern Mediterranean  SEX_FMLE     2015  10.41785  13.39566
# 11                 Africa  SEX_BTSX     2016   4.62815  16.73667
# 14                 Europe   SEX_MLE     2013   1.68666   3.57636
#
#     NumericValue SpatialDim age_group
# 3        2.55050        PRY     Adult
# 4       11.76163        YEM     Adult
# 5       11.86974        PAK     Adult
# 11       9.83577        GNQ     Adult
# 14       2.52340        UZB     Adult

# %%
columns_to_rename = {'TimeDim': 'Year', 'Dim1': 'Gender', 'NumericValue': 'Mean_Estimate', 'Low': 'LowerBound', 'High': 'UpperBound', 'ParentLocation': 'Region', 'SpatialDim': 'Country'}
df_obesity.rename(columns=columns_to_rename, inplace=True)

# %%
print(df_obesity.head())
# Out:
#                    Region    Gender  Year  LowerBound  UpperBound  \
# 1                  Africa  SEX_FMLE  2017     3.14044     5.40993
# 4   Eastern Mediterranean  SEX_BTSX  2018    34.92298    41.87444
# 5                  Europe  SEX_BTSX  2022    28.31155    34.41646
# 9                  Africa   SEX_MLE  2017     1.22144     2.41332
# 13               Americas  SEX_FMLE  2022    31.74306    44.23656
#
#     Mean_Estimate Country age_group
# 1         4.17558     TCD     Adult
# 4        38.30225     SAU     Adult
# 5        31.29533     CZE     Adult
# 9         1.76076     MWI     Adult
# 13       37.80555     GUY     Adult

# %%
columns_to_rename = {'TimeDim': 'Year', 'Dim1': 'Gender', 'NumericValue': 'Mean_Estimate', 'Low': 'LowerBound', 'High': 'UpperBound', 'ParentLocation': 'Region', 'SpatialDim': 'Country'}
df_malnutrition.rename(columns=columns_to_rename, inplace=True)

# %%
print(df_malnutrition.head())
# Out:
#                    Region    Gender  Year  LowerBound  UpperBound  \
# 3                Americas   SEX_MLE  2017     1.10349     4.62184
# 4   Eastern Mediterranean   SEX_MLE  2014     7.98273    15.97617
# 5   Eastern Mediterranean  SEX_FMLE  2015    10.41785    13.39566
# 11                 Africa  SEX_BTSX  2016     4.62815    16.73667
# 14                 Europe   SEX_MLE  2013     1.68666     3.57636
#
#     Mean_Estimate Country age_group
# 3         2.55050     PRY     Adult
# 4        11.76163     YEM     Adult
# 5        11.86974     PAK     Adult
# 11        9.83577     GNQ     Adult
# 14        2.52340     UZB     Adult

# %%
df_obesity['Gender'] = df_obesity['Gender'].replace({'SEX_MLE': 'Male', 'SEX_FMLE': 'Female', 'SEX_BTSX': 'Both'})

# %%
print(df_obesity.head())
# Out:
#                    Region  Gender  Year  LowerBound  UpperBound  \
# 1                  Africa  Female  2017     3.14044     5.40993
# 4   Eastern Mediterranean    Both  2018    34.92298    41.87444
# 5                  Europe    Both  2022    28.31155    34.41646
# 9                  Africa    Male  2017     1.22144     2.41332
# 13               Americas  Female  2022    31.74306    44.23656
#
#     Mean_Estimate Country age_group
# 1         4.17558     TCD     Adult
# 4        38.30225     SAU     Adult
# 5        31.29533     CZE     Adult
# 9         1.76076     MWI     Adult
# 13       37.80555     GUY     Adult

# %%
df_malnutrition['Gender'] = df_malnutrition['Gender'].replace({'SEX_MLE': 'Male', 'SEX_FMLE': 'Female', 'SEX_BTSX': 'Both'})

# %%
print(df_malnutrition.head())
# Out:
#                    Region  Gender  Year  LowerBound  UpperBound  \
# 3                Americas    Male  2017     1.10349     4.62184
# 4   Eastern Mediterranean    Male  2014     7.98273    15.97617
# 5   Eastern Mediterranean  Female  2015    10.41785    13.39566
# 11                 Africa    Both  2016     4.62815    16.73667
# 14                 Europe    Male  2013     1.68666     3.57636
#
#     Mean_Estimate Country age_group
# 3         2.55050     PRY     Adult
# 4        11.76163     YEM     Adult
# 5        11.86974     PAK     Adult
# 11        9.83577     GNQ     Adult
# 14        2.52340     UZB     Adult

# %%
# !pip install pycountry
# Out:
# Requirement already satisfied: pycountry in c:\users\alber\anaconda3\lib\site-packages (24.6.1)

# %%
import pycountry
special_cases = {
                    'GLOBAL': 'Global',
                    'WB_LMI': 'Low & Middle Income',
                    'WB_HI': 'High Income',
                    'WB_LI': 'Low Income',
                    'EMR': 'Eastern Mediterranean Region',
                    'EUR': 'Europe',
                    'AFR': 'Africa',
                    'SEAR': 'South-East Asia Region',
                    'WPR': 'Western Pacific Region',
                    'AMR': 'Americas Region',
                    'WB_UMI': 'Upper Middle Income'
}

df_obesity['Country'] = df_obesity['Country'].apply(lambda code: (
    special_cases[code] if code in special_cases else
    pycountry.countries.get(alpha_3=code).name if pycountry.countries.get(alpha_3=code) else code
) if isinstance(code, str) else code)

# %%
print(df_obesity.head())
# Out:
#                    Region  Gender  Year  LowerBound  UpperBound  \
# 1                  Africa  Female  2017     3.14044     5.40993
# 4   Eastern Mediterranean    Both  2018    34.92298    41.87444
# 5                  Europe    Both  2022    28.31155    34.41646
# 9                  Africa    Male  2017     1.22144     2.41332
# 13               Americas  Female  2022    31.74306    44.23656
#
#     Mean_Estimate       Country age_group
# 1         4.17558          Chad     Adult
# 4        38.30225  Saudi Arabia     Adult
# 5        31.29533       Czechia     Adult
# 9         1.76076        Malawi     Adult
# 13       37.80555        Guyana     Adult

# %%
df_malnutrition['Country'] = df_malnutrition['Country'].apply(lambda code: (
    special_cases[code] if code in special_cases else
    pycountry.countries.get(alpha_3=code).name if pycountry.countries.get(alpha_3=code) else code
) if isinstance(code, str) else code)

# %%
print(df_malnutrition.head())
# Out:
#                    Region  Gender  Year  LowerBound  UpperBound  \
# 3                Americas    Male  2017     1.10349     4.62184
# 4   Eastern Mediterranean    Male  2014     7.98273    15.97617
# 5   Eastern Mediterranean  Female  2015    10.41785    13.39566
# 11                 Africa    Both  2016     4.62815    16.73667
# 14                 Europe    Male  2013     1.68666     3.57636
#
#     Mean_Estimate            Country age_group
# 3         2.55050           Paraguay     Adult
# 4        11.76163              Yemen     Adult
# 5        11.86974           Pakistan     Adult
# 11        9.83577  Equatorial Guinea     Adult
# 14        2.52340         Uzbekistan     Adult

# %%
# Adding Columns

# %%
df_obesity['CI_Width'] = df_obesity['UpperBound'] - df_obesity['LowerBound']

# %%
print(df_obesity.head())
# Out:
#                    Region  Gender  Year  LowerBound  UpperBound  \
# 1                  Africa  Female  2017     3.14044     5.40993
# 4   Eastern Mediterranean    Both  2018    34.92298    41.87444
# 5                  Europe    Both  2022    28.31155    34.41646
# 9                  Africa    Male  2017     1.22144     2.41332
# 13               Americas  Female  2022    31.74306    44.23656
#
#     Mean_Estimate       Country age_group  CI_Width
# 1         4.17558          Chad     Adult   2.26949
# 4        38.30225  Saudi Arabia     Adult   6.95146
# 5        31.29533       Czechia     Adult   6.10491
# 9         1.76076        Malawi     Adult   1.19188
# 13       37.80555        Guyana     Adult  12.49350

# %%
df_malnutrition['CI_Width'] = df_malnutrition['UpperBound'] - df_malnutrition['LowerBound']

# %%
print(df_malnutrition.head())
# Out:
#                    Region  Gender  Year  LowerBound  UpperBound  \
# 3                Americas    Male  2017     1.10349     4.62184
# 4   Eastern Mediterranean    Male  2014     7.98273    15.97617
# 5   Eastern Mediterranean  Female  2015    10.41785    13.39566
# 11                 Africa    Both  2016     4.62815    16.73667
# 14                 Europe    Male  2013     1.68666     3.57636
#
#     Mean_Estimate            Country age_group  CI_Width
# 3         2.55050           Paraguay     Adult   3.51835
# 4        11.76163              Yemen     Adult   7.99344
# 5        11.86974           Pakistan     Adult   2.97781
# 11        9.83577  Equatorial Guinea     Adult  12.10852
# 14        2.52340         Uzbekistan     Adult   1.88970

# %%
def categorize_obesity(value):
    if value >= 30:
        return 'High'
    elif 25 <= value <30:
        return 'Moderate'
    else:
        return 'Low'

df_obesity['obesity_level'] = df_obesity['Mean_Estimate'].apply(categorize_obesity)

# %%
print(df_obesity.head())
# Out:
#                    Region  Gender  Year  LowerBound  UpperBound  \
# 1                  Africa  Female  2017     3.14044     5.40993
# 4   Eastern Mediterranean    Both  2018    34.92298    41.87444
# 5                  Europe    Both  2022    28.31155    34.41646
# 9                  Africa    Male  2017     1.22144     2.41332
# 13               Americas  Female  2022    31.74306    44.23656
#
#     Mean_Estimate       Country age_group  CI_Width obesity_level
# 1         4.17558          Chad     Adult   2.26949           Low
# 4        38.30225  Saudi Arabia     Adult   6.95146          High
# 5        31.29533       Czechia     Adult   6.10491          High
# 9         1.76076        Malawi     Adult   1.19188           Low
# 13       37.80555        Guyana     Adult  12.49350          High

# %%
def categorize_malnutrition(value):
    if value >= 20:
        return 'High'
    elif 10 <= value <20:
        return 'Moderate'
    else:
        return 'Low'

df_malnutrition['malnutrition_level'] = df_malnutrition['Mean_Estimate'].apply(categorize_malnutrition)

# %%
print(df_malnutrition.head())
# Out:
#                    Region  Gender  Year  LowerBound  UpperBound  \
# 3                Americas    Male  2017     1.10349     4.62184
# 4   Eastern Mediterranean    Male  2014     7.98273    15.97617
# 5   Eastern Mediterranean  Female  2015    10.41785    13.39566
# 11                 Africa    Both  2016     4.62815    16.73667
# 14                 Europe    Male  2013     1.68666     3.57636
#
#     Mean_Estimate            Country age_group  CI_Width malnutrition_level
# 3         2.55050           Paraguay     Adult   3.51835                Low
# 4        11.76163              Yemen     Adult   7.99344           Moderate
# 5        11.86974           Pakistan     Adult   2.97781           Moderate
# 11        9.83577  Equatorial Guinea     Adult  12.10852                Low
# 14        2.52340         Uzbekistan     Adult   1.88970                Low

# %%
# EDA

# %%
df_obesity.isnull().sum()
# Out:
# Region           1452
# Gender              0
# Year                0
# LowerBound          0
# UpperBound          0
# Mean_Estimate       0
# Country             0
# age_group           0
# CI_Width            0
# obesity_level       0
# dtype: int64

# %%
df_obesity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27720 entries, 1 to 83159
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Region         26268 non-null  object
#  1   Gender         27720 non-null  object
#  2   Year           27720 non-null  int64
#  3   LowerBound     27720 non-null  float64
#  4   UpperBound     27720 non-null  float64
#  5   Mean_Estimate  27720 non-null  float64
#  6   Country        27720 non-null  object
#  7   age_group      27720 non-null  object
#  8   CI_Width       27720 non-null  float64
#  9   obesity_level  27720 non-null  object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 2.3+ MB

# %%
df_obesity.describe()
# Out:
#                Year    LowerBound    UpperBound  Mean_Estimate      CI_Width
# count  27720.000000  27720.000000  27720.000000   27720.000000  27720.000000
# mean    2017.000000      9.393155     17.068489      12.761041      7.675334
# std        3.162335      9.893854     12.395013      10.858925      6.616899
# min     2012.000000      0.077540      0.547850       0.265670      0.216700
# 25%     2014.000000      2.354430      7.875503       4.753960      2.926715
# 50%     2017.000000      6.506535     13.704380       9.944540      5.480535
# 75%     2020.000000     12.697755     23.986050      17.482418     10.338880
# max     2022.000000     74.365370     87.868510      80.609250     40.554060

# %%
df_obesity.shape
# Out:
# (27720, 10)

# %%
df_malnutrition.isnull().sum()
# Out:
# Region                1452
# Gender                   0
# Year                     0
# LowerBound               0
# UpperBound               0
# Mean_Estimate            0
# Country                  0
# age_group                0
# CI_Width                 0
# malnutrition_level       0
# dtype: int64

# %%
df_malnutrition.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27720 entries, 3 to 83156
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Region              26268 non-null  object
#  1   Gender              27720 non-null  object
#  2   Year                27720 non-null  int64
#  3   LowerBound          27720 non-null  float64
#  4   UpperBound          27720 non-null  float64
#  5   Mean_Estimate       27720 non-null  float64
#  6   Country             27720 non-null  object
#  7   age_group           27720 non-null  object
#  8   CI_Width            27720 non-null  float64
#  9   malnutrition_level  27720 non-null  object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 2.3+ MB

# %%
df_malnutrition.describe()
# Out:
#                Year    LowerBound    UpperBound  Mean_Estimate      CI_Width
# count  27720.000000  27720.000000  27720.000000   27720.000000  27720.000000
# mean    2017.000000      3.397094      8.147889       5.354451      4.750795
# std        3.162335      3.908061      6.443692       4.811220      4.257684
# min     2012.000000      0.023700      0.354830       0.175310      0.166680
# 25%     2014.000000      1.053662      3.143305       2.039283      1.603222
# 50%     2017.000000      1.907975      6.095555       3.597790      3.351095
# 75%     2020.000000      4.186443     11.526302       7.335245      6.530875
# max     2022.000000     31.365400     43.680290      35.894110     26.701740

# %%
df_malnutrition.shape
# Out:
# (27720, 10)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#df_obesity

# %%
# Histogram for Mean_Estimate
sns.histplot(df_obesity['Mean_Estimate'], bins=30, kde=True)
plt.title('Distribution of Mean_Estimate')
plt.xlabel('Mean_Estimate')
plt.ylabel('Frequency')
plt.show()

# %%
# Boxplot for CI_Width
sns.boxplot(x=df_obesity['CI_Width'], color='orange')
plt.title('Boxplot of CI_Width')
plt.show()

# %%
#Barplot
plt.figure(figsize=(8, 5))
sns.barplot(x='Gender', y='Mean_Estimate', data=df_obesity, estimator='mean', errorbar='sd', hue='obesity_level', palette='pastel')
plt.title('Average Mean Estimate by Gender')
plt.show()

# %%
# Heatmap
heatmap_data = df_obesity.pivot_table(values='Mean_Estimate', index='Region', columns='Year', aggfunc='mean')
plt.figure(figsize=(8, 4))
sns.heatmap(heatmap_data, cmap='YlGnBu', annot=True, linewidths=0.5)

plt.title('Mean Estimate Heatmap by Region and Year')
plt.xlabel('Year')
plt.ylabel('Region')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
#scatterplot
plt.figure(figsize=(8, 5))
sns.scatterplot(x='CI_Width', y='Mean_Estimate', hue='obesity_level', data=df_obesity)
plt.title('CI Width vs Mean Estimate')
plt.show()

# %%
#Lineplot
yearly_avg = df_obesity.groupby('Year')['Mean_Estimate'].mean().reset_index()

plt.figure(figsize=(8, 5))
sns.lineplot(x='Year', y='Mean_Estimate', data=yearly_avg, marker='o')
plt.title('Mean Estimate Trend Over Years')
plt.xlabel('Year')
plt.ylabel('Mean Estimate')
plt.grid(True)
plt.show()

# %%
#Countplot
plt.figure(figsize=(6, 4))
sns.countplot(x='obesity_level', data=df_obesity, )
plt.title('Count of Obesity Levels')
plt.show()

# %%
# df_malnutrition

# %%
# Histogram for Mean_Estimate
sns.histplot(df_malnutrition['Mean_Estimate'], bins=50, kde=True, color='yellowgreen')
plt.title('Distribution of Mean_Estimate')
plt.xlabel('Mean_Estimate')
plt.ylabel('Frequency')
plt.show()

# %%
#Lineplot
yearly_avg = df_malnutrition.groupby('Year')['Mean_Estimate'].mean().reset_index()

plt.figure(figsize=(8, 5))
sns.lineplot(x='Year', y='Mean_Estimate', data=yearly_avg,)
plt.title('Mean Estimate Trend Over Years')
plt.xlabel('Year')
plt.ylabel('Mean Estimate')
plt.grid(True)
plt.show()

# %%
#scatter plot
plt.figure(figsize=(8, 5))
sns.boxplot(x='malnutrition_level', y='Mean_Estimate', data=df_malnutrition, hue='malnutrition_level', palette='pastel')
plt.title('Mean Estimate by malnutrition Level')
plt.show()

# %%
#Obesity vs Malnutrition

# %%
df_combined = pd.merge(df_obesity, df_malnutrition, 
                       on=['Country', 'Year', 'Gender'], 
                       suffixes=('_obesity', '_malnutrition'))

# %%
#Obesity vs Malnutrition 
print(df_combined.head())
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df_combined,
                x='Mean_Estimate_obesity',
                y='Mean_Estimate_malnutrition',
                hue='Region_obesity',
                style='Gender')

plt.title('Obesity vs Malnutrition (Mean Estimates)')
plt.xlabel('Obesity Mean Estimate')
plt.ylabel('Malnutrition Mean Estimate')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
#           Region_obesity  Gender  Year  LowerBound_obesity  \
# 0                 Africa  Female  2017             3.14044
# 1                 Africa  Female  2017             3.14044
# 2                 Africa  Female  2017             3.14044
# 3                 Africa  Female  2017             3.14044
# 4  Eastern Mediterranean    Both  2018            34.92298
#
#    UpperBound_obesity  Mean_Estimate_obesity       Country age_group_obesity  \
# 0             5.40993                4.17558          Chad             Adult
# 1             5.40993                4.17558          Chad             Adult
# 2             5.40993                4.17558          Chad             Adult
# 3             5.40993                4.17558          Chad             Adult
# 4            41.87444               38.30225  Saudi Arabia             Adult
#
#    CI_Width_obesity obesity_level    Region_malnutrition  \
# 0           2.26949           Low                 Africa
# 1           2.26949           Low                 Africa
# 2           2.26949           Low                 Africa
# 3           2.26949           Low                 Africa
# 4           6.95146          High  Eastern Mediterranean
#
#    LowerBound_malnutrition  UpperBound_malnutrition  \
# 0                 13.05965                 21.16546
# 1                  4.39110                 13.20613
# 2                  5.08727                 11.93803
# 3                  2.87659                 16.46157
# 4                  2.93548                  5.06914
#
#    Mean_Estimate_malnutrition age_group_malnutrition  CI_Width_malnutrition  \
# 0                    17.00765                  Adult                8.10581
# 1                     8.19519                  Child                8.81503
# 2                     8.20507                  Child                6.85076
# 3                     8.18053                  Child               13.58498
# 4                     3.91602                  Adult                2.13366
#
#   malnutrition_level
# 0           Moderate
# 1                Low
# 2                Low
# 3                Low
# 4                Low

# %%
#heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df_combined[[
    'Mean_Estimate_obesity', 'CI_Width_obesity',
    'Mean_Estimate_malnutrition', 'CI_Width_malnutrition'
]].corr(), annot=True, cmap='coolwarm', fmt=".2f")

plt.title('Correlation Heatmap: Obesity vs Malnutrition')
plt.show()

# %%
#lineplot
plt.figure(figsize=(8, 6))
sns.lineplot(data=df_combined, x='Year', y='Mean_Estimate_obesity', hue='Region_obesity')

plt.title('Obesity Mean Estimate Over Time by Region')
plt.xlabel('Year')
plt.ylabel('Obesity Mean Estimate')

plt.tight_layout()
plt.show()

# %%
#Creating database using mysql

# %%
pip install pymysql
# Out:
# Requirement already satisfied: pymysql in c:\users\alber\anaconda3\lib\site-packages (1.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pymysql

# %%
myconnection = pymysql.connect(host = '127.0.0.1', user = 'root', passwd = 'Alby@0308')

# %%
cur = myconnection.cursor()

# %%
cur.execute("create database if not exists WHO")
# Out:
# 1

# %%
myconnection = pymysql.connect(host = '127.0.0.1', user = 'root', passwd = 'Alby@0308', database = 'WHO')

# %%
cur = myconnection.cursor()

# %%
cur.execute("""create table if not exists obesity(Region varchar(50),Gender varchar(10),Year int,LowerBound float,UpperBound float,Mean_Estimate float,Country varchar(50),age_group varchar(20),CI_Width float,obesity_level varchar(20))""")
# Out:
# 0

# %%
cur.execute("""create table if not exists malnutrition(Region varchar(50),Gender varchar(10),Year int,LowerBound float,UpperBound float,Mean_Estimate float,Country varchar(50),age_group varchar(20),CI_Width float,malnutrition_level varchar(20))""")
# Out:
# 0

# %%
for index, row in df_obesity.iterrows():
 cur.execute('''insert into obesity(Region, Gender, Year, LowerBound, UpperBound, Mean_Estimate, Country, age_group, CI_Width, obesity_level) values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)''', (row["Region"], row["Gender"], row["Year"], row["LowerBound"], row["UpperBound"], row["Mean_Estimate"], row["Country"], row["age_group"], row["CI_Width"], row["obesity_level"]))
myconnection.commit()

# %%
for index, row in df_malnutrition.iterrows():
 cur.execute('''insert into malnutrition(Region, Gender, Year, LowerBound, UpperBound, Mean_Estimate, Country, age_group, CI_Width, malnutrition_level) values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)''', (row["Region"], row["Gender"], row["Year"], row["LowerBound"], row["UpperBound"], row["Mean_Estimate"], row["Country"], row["age_group"], row["CI_Width"], row["malnutrition_level"]))
myconnection.commit()

# %%
# Obesity Table (10 Queries)

# %%
#1.Top 5 regions with the highest average obesity levels in the most recent year(2022)
query = '''SELECT Region, AVG(Mean_Estimate) AS Avg_Obesity FROM obesity WHERE Year = 2022 GROUP BY Region ORDER BY Avg_Obesity DESC LIMIT 5'''

# %%
cur.execute(query)
result=cur.fetchall()
df=pd.DataFrame(result,columns=[i[0]for i in cur.description])
df
# Out:
#                   Region  Avg_Obesity
# 0        Western Pacific    23.009388
# 1               Americas    21.213601
# 2  Eastern Mediterranean    18.126910
# 3                 Europe    12.987338
# 4                   None    11.462648

# %%
#2.Top 5 countries with highest obesity estimates
query = '''SELECT Country, MAX(Mean_Estimate) AS Max_Obesity FROM obesity GROUP BY Country ORDER BY Max_Obesity DESC LIMIT 5'''

# %%
cur.execute(query)
result=cur.fetchall()
df=pd.DataFrame(result,columns=[i[0]for i in cur.description])
df
# Out:
#           Country  Max_Obesity
# 0  American Samoa      80.6093
# 1           Tonga      79.0533
# 2           Samoa      72.6159
# 3         Tokelau      72.4867
# 4    Cook Islands      71.5139

# %%
#3.Obesity trend in India over the years(Mean_estimate)
query = '''SELECT Year, AVG(Mean_Estimate) AS Avg_Obesity FROM obesity WHERE Country = 'India'GROUP BY Year ORDER BY Year'''

# %%
cur.execute(query)
result=cur.fetchall()
df=pd.DataFrame(result,columns=[i[0]for i in cur.description])
df
# Out:
#     Year  Avg_Obesity
# 0   2012     2.473178
# 1   2013     2.634653
# 2   2014     2.798748
# 3   2015     2.972814
# 4   2016     3.159577
# 5   2017     3.362175
# 6   2018     3.579292
# 7   2019     3.809013
# 8   2020     4.051149
# 9   2021     4.307815
# 10  2022     4.579180

# %%
#4.Average obesity by gender
query = '''SELECT Gender, AVG(Mean_Estimate) as avg_Obesity from obesity GROUP BY Gender'''

# %%
cur.execute(query)
result=cur.fetchall()
df=pd.DataFrame(result,columns=[i[0]for i in cur.description])
df
# Out:
#    Gender  avg_Obesity
# 0    Male    12.776696
# 1  Female    12.724456
# 2    Both    12.781970

# %%
#5.Country count by obesity level category and age group
query = '''SELECT obesity_level, age_group, COUNT(DISTINCT Country) AS Country_Count FROM obesity GROUP BY obesity_level, age_group'''

# %%
cur.execute(query)
result=cur.fetchall()
df=pd.DataFrame(result,columns=[i[0]for i in cur.description])
df
# Out:
#   obesity_level age_group  Country_Count
# 0          High     Adult             94
# 1          High     Child             11
# 2           Low     Adult            176
# 3           Low     Child            210
# 4      Moderate     Adult             99
# 5      Moderate     Child             26

# %%
#6.Top 5 countries least reliable countries(with highest CI_Width) and Top 5 most consistent countries (smallest average CI_Width)
query = '''SELECT Country, AVG(CI_Width) AS Avg_CI FROM obesity GROUP BY Country ORDER BY Avg_CI DESC LIMIT 5'''

# %%
cur.execute(query)
result=cur.fetchall()
df=pd.DataFrame(result,columns=[i[0]for i in cur.description])
df
# Out:
#                   Country    Avg_CI
# 0                  Global  0.708952
# 1     Low & Middle Income  0.861059
# 2  South-East Asia Region  1.017775
# 3                   India  1.140133
# 4                   Japan  1.155902

# %%
query = '''SELECT Country, AVG(CI_Width) AS Avg_CI FROM obesity GROUP BY Country ORDER BY Avg_CI ASC LIMIT 5'''

# %%
cur.execute(query)
result=cur.fetchall()
df=pd.DataFrame(result,columns=[i[0]for i in cur.description])
df
# Out:
#                   Country    Avg_CI
# 0                  Global  0.708952
# 1     Low & Middle Income  0.861059
# 2  South-East Asia Region  1.017775
# 3                   India  1.140133
# 4                   Japan  1.155902

# %%
#7.Average obesity by age group
query = '''SELECT age_group, avg(Mean_Estimate) as avg_Obesity FROM obesity GROUP BY age_group'''

# %%
cur.execute(query)
result=cur.fetchall()
df=pd.DataFrame(result,columns=[i[0]for i in cur.description])
df
# Out:
#   age_group  avg_Obesity
# 0     Adult    21.833224
# 1     Child     9.736980

# %%
#8.Top 10 Countries with consistent low obesity (low average + low CI)over the years
query = '''SELECT Country, AVG(Mean_Estimate) AS Avg_Obesity, AVG(CI_Width) AS Avg_CI FROM obesity GROUP BY Country HAVING Avg_Obesity < 20 AND Avg_CI < 5 ORDER BY Avg_Obesity ASC, Avg_CI ASC LIMIT 10'''

# %%
cur.execute(query)
result=cur.fetchall()
df=pd.DataFrame(result,columns=[i[0]for i in cur.description])
df
# Out:
#         Country  Avg_Obesity    Avg_CI
# 0   Timor-Leste     0.994067  1.273569
# 1      Ethiopia     1.491995  1.589414
# 2  Burkina Faso     1.721496  1.531514
# 3        Rwanda     1.767194  2.360578
# 4    Bangladesh     1.976673  1.663507
# 5    Madagascar     1.984110  4.356886
# 6        Malawi     2.391324  2.632713
# 7         Nepal     2.494255  3.098051
# 8    Mozambique     2.772244  2.764630
# 9         Niger     3.080739  4.666968

# %%
#9.Countries where female obesity exceeds male by large margin (same year)
query = '''SELECT f.Country, f.Year, f.Mean_Estimate AS Female_Obesity, m.Mean_Estimate AS Male_Obesity,(f.Mean_Estimate - m.Mean_Estimate) AS Difference
FROM obesity f JOIN obesity m ON f.Country = m.Country AND f.Year = m.Year WHERE f.Gender = 'Female' AND m.Gender = 'Male' AND (f.Mean_Estimate - m.Mean_Estimate) > 5 ORDER BY Difference DESC limit 10'''

# %%
cur.execute(query)
result=cur.fetchall()
df=pd.DataFrame(result,columns=[i[0]for i in cur.description])
df
# Out:
#           Country  Year  Female_Obesity  Male_Obesity  Difference
# 0  American Samoa  2012         76.9838       23.7296   53.254200
# 1  American Samoa  2012         76.9838       23.7296   53.254200
# 2  American Samoa  2012         76.9838       23.7296   53.254200
# 3  American Samoa  2012         76.9838       23.7296   53.254200
# 4  American Samoa  2012         76.9838       23.8665   53.117321
# 5  American Samoa  2012         76.9838       23.8665   53.117321
# 6  American Samoa  2012         76.9838       23.8665   53.117321
# 7  American Samoa  2012         76.9838       23.8665   53.117321
# 8  American Samoa  2012         76.9838       24.1169   52.866899
# 9  American Samoa  2012         76.9838       24.1169   52.866899

# %%
#10.Global average obesity percentage per year
query = '''SELECT Year, AVG(Mean_Estimate) AS Global_Avg_Obesity FROM obesity GROUP BY Year ORDER BY Year'''

# %%
cur.execute(query)
result=cur.fetchall()
df=pd.DataFrame(result,columns=[i[0]for i in cur.description])
df
# Out:
#     Year  Global_Avg_Obesity
# 0   2012           11.061970
# 1   2013           11.359638
# 2   2014           11.670344
# 3   2015           11.994231
# 4   2016           12.333907
# 5   2017           12.689997
# 6   2018           13.060297
# 7   2019           13.444604
# 8   2020           13.843002
# 9   2021           14.250923
# 10  2022           14.662533

# %%
#malnutrition query

# %%
#1.
query = '''select age_group, AVG(Mean_Estimate) as avg_malnutrition from malnutrition group by age_group order by avg_malnutrition desc'''

# %%
cur.execute(query)
result=cur.fetchall()
df=pd.DataFrame(result,columns=[i[0]for i in cur.description])
df
# Out:
#   age_group  avg_malnutrition
# 0     Adult          5.940619
# 1     Child          5.159062

# %%
#2.
query = '''SELECT country, AVG(mean_estimate) AS avg_malnutrition FROM malnutrition GROUP BY country ORDER BY avg_malnutrition DESC LIMIT 5'''

# %%
cur.execute(query)
result=cur.fetchall()
df=pd.DataFrame(result,columns=[i[0]for i in cur.description])
df
# Out:
#                   country  avg_malnutrition
# 0                   India         22.142361
# 1  South-East Asia Region         19.238903
# 2              Bangladesh         18.245769
# 3               Sri Lanka         17.871908
# 4                 Eritrea         17.472509

# %%
#3.
query = '''SELECT year, AVG(mean_estimate) AS avg_malnutrition FROM malnutrition WHERE region = 'Africa' GROUP BY year ORDER BY year'''

# %%
cur.execute(query)
result=cur.fetchall()
df=pd.DataFrame(result,columns=[i[0]for i in cur.description])
df
# Out:
#     year  avg_malnutrition
# 0   2012          8.849655
# 1   2013          8.749857
# 2   2014          8.662762
# 3   2015          8.587719
# 4   2016          8.523125
# 5   2017          8.466465
# 6   2018          8.414722
# 7   2019          8.369700
# 8   2020          8.331320
# 9   2021          8.298626
# 10  2022          8.270096

# %%
#4.
query = '''SELECT gender, AVG(mean_estimate) AS avg_malnutrition FROM malnutrition GROUP BY gender'''

# %%
cur.execute(query)
result=cur.fetchall()
df=pd.DataFrame(result,columns=[i[0]for i in cur.description])
df
# Out:
#    gender  avg_malnutrition
# 0  Female          4.675483
# 1    Male          6.026317
# 2    Both          5.361553

# %%
#5.
query = '''SELECT age_group, AVG(CI_Width) AS avg_CI_width FROM malnutrition GROUP BY age_group ORDER BY avg_CI_width DESC'''

# %%
cur.execute(query)
result=cur.fetchall()
df=pd.DataFrame(result,columns=[i[0]for i in cur.description])
df
# Out:
#   age_group  avg_CI_width
# 0     Child      5.103133
# 1     Adult      3.693780

# %%
#6.
query = '''SELECT 
    country, 
    year, 
    AVG(mean_estimate) AS avg_malnutrition
FROM 
    malnutrition
WHERE 
    country IN ('India', 'Nigeria', 'Brazil')
GROUP BY 
    country, year
ORDER BY 
    country, year'''

# %%
cur.execute(query)
result=cur.fetchall()
df=pd.DataFrame(result,columns=[i[0]for i in cur.description])
df
# Out:
#     country  year  avg_malnutrition
# 0    Brazil  2012          2.838653
# 1    Brazil  2013          2.781387
# 2    Brazil  2014          2.735034
# 3    Brazil  2015          2.698948
# 4    Brazil  2016          2.672242
# 5    Brazil  2017          2.653567
# 6    Brazil  2018          2.641574
# 7    Brazil  2019          2.634596
# 8    Brazil  2020          2.629412
# 9    Brazil  2021          2.626638
# 10   Brazil  2022          2.626852
# 11    India  2012         25.192437
# 12    India  2013         24.608118
# 13    India  2014         24.013358
# 14    India  2015         23.399620
# 15    India  2016         22.771375
# 16    India  2017         22.140418
# 17    India  2018         21.511675
# 18    India  2019         20.887198
# 19    India  2020         20.273681
# 20    India  2021         19.676078
# 21    India  2022         19.092014
# 22  Nigeria  2012         11.248457
# 23  Nigeria  2013         11.316422
# 24  Nigeria  2014         11.416175
# 25  Nigeria  2015         11.541387
# 26  Nigeria  2016         11.686107
# 27  Nigeria  2017         11.842103
# 28  Nigeria  2018         12.001993
# 29  Nigeria  2019         12.168213
# 30  Nigeria  2020         12.340928
# 31  Nigeria  2021         12.519244
# 32  Nigeria  2022         12.700027

# %%
#7.
query = '''SELECT region, AVG(mean_estimate) AS avg_malnutrition FROM malnutrition GROUP BY region ORDER BY avg_malnutrition ASC'''

# %%
cur.execute(query)
result=cur.fetchall()
df=pd.DataFrame(result,columns=[i[0]for i in cur.description])
df
# Out:
#                   region  avg_malnutrition
# 0                 Europe          2.426759
# 1               Americas          3.174752
# 2        Western Pacific          3.220453
# 3  Eastern Mediterranean          6.661349
# 4                   None          8.354200
# 5                 Africa          8.502186
# 6        South-East Asia         13.283206

# %%
#8.
query = '''SELECT country, MAX(mean_estimate) - MIN(mean_estimate) AS increase_in_malnutrition FROM malnutrition GROUP BY country HAVING increase_in_malnutrition > 0 ORDER BY increase_in_malnutrition DESC'''

# %%
cur.execute(query)
result=cur.fetchall()
df=pd.DataFrame(result,columns=[i[0]for i in cur.description])
df
# Out:
#             country  increase_in_malnutrition
# 0           Eritrea                 28.026052
# 1          Ethiopia                 21.750081
# 2           Somalia                 20.832830
# 3             India                 18.827341
# 4          Pakistan                 17.736900
# ..              ...                       ...
# 205    Cook Islands                  1.187260
# 206            Peru                  1.160100
# 207  American Samoa                  0.900440
# 208            Niue                  0.896480
# 209           Tonga                  0.893910
#
# [210 rows x 2 columns]

# %%
#9.
query = '''SELECT year, MIN(mean_estimate) AS min_malnutrition, MAX(mean_estimate) AS max_malnutrition FROM malnutrition GROUP BY year ORDER BY year'''

# %%
cur.execute(query)
result=cur.fetchall()
df=pd.DataFrame(result,columns=[i[0]for i in cur.description])
df
# Out:
#     year  min_malnutrition  max_malnutrition
# 0   2012           0.17531           35.8941
# 1   2013           0.17642           35.6944
# 2   2014           0.17777           35.4982
# 3   2015           0.17844           35.3130
# 4   2016           0.17880           35.1477
# 5   2017           0.17929           34.9979
# 6   2018           0.17980           34.8562
# 7   2019           0.18043           34.7160
# 8   2020           0.18199           34.5784
# 9   2021           0.18472           34.4292
# 10  2022           0.18817           34.2620

# %%
#10.
query = '''SELECT * FROM malnutrition WHERE CI_Width > 5 ORDER BY CI_Width DESC'''

# %%
cur.execute(query)
result=cur.fetchall()
df=pd.DataFrame(result,columns=[i[0]for i in cur.description])
df
# Out:
#                 Region  Gender  Year  LowerBound  UpperBound  Mean_Estimate  \
# 0               Africa    Male  2022     5.73517    32.43690       16.94180
# 1               Africa    Male  2022     5.73517    32.43690       16.94180
# 2               Africa    Male  2021     6.16167    31.84100       16.99200
# 3               Africa    Male  2021     6.16167    31.84100       16.99200
# 4               Africa    Male  2020     6.61769    31.20410       17.04640
# ...                ...     ...   ...         ...         ...            ...
# 19137           Africa  Female  2018     1.33781     6.33937        3.27296
# 19138  Western Pacific  Female  2021     5.22967    10.23120        7.55125
# 19139  Western Pacific  Female  2021     5.22967    10.23120        7.55125
# 19140           Africa    Male  2021     2.84602     7.84653        4.99000
# 19141           Africa    Male  2021     2.84602     7.84653        4.99000
#
#             Country age_group  CI_Width malnutrition_level
# 0           Senegal     Child  26.70170           Moderate
# 1           Senegal     Child  26.70170           Moderate
# 2           Senegal     Child  25.67930           Moderate
# 3           Senegal     Child  25.67930           Moderate
# 4           Senegal     Child  24.58640           Moderate
# ...             ...       ...       ...                ...
# 19137       Comoros     Child   5.00156                Low
# 19138   Philippines     Child   5.00152                Low
# 19139   Philippines     Child   5.00152                Low
# 19140  Sierra Leone     Child   5.00051                Low
# 19141  Sierra Leone     Child   5.00051                Low
#
# [19142 rows x 10 columns]

# %%
#combined qquery

# %%
#1.
query = '''SELECT o.country, AVG(o.mean_estimate) AS avg_obesity, AVG(m.mean_estimate) AS avg_malnutrition FROM obesity o JOIN malnutrition m ON o.country = m.country WHERE o.country IN ('India', 'Brazil', 'USA', 'Nigeria', 'Mexico') GROUP BY o.country'''

# %%
cur.execute(query)
result=cur.fetchall()
df=pd.DataFrame(result,columns=[i[0]for i in cur.description])
df
# Out:
#    country  avg_obesity  avg_malnutrition
# 0  Nigeria     4.467604         11.889187
# 1    India     3.429781         22.142361
# 2   Brazil    16.613028          2.685355
# 3   Mexico    20.062568          1.845167

# %%
#2.
query = '''SELECT o.gender, AVG(o.mean_estimate) AS avg_obesity, AVG(m.mean_estimate) AS avg_malnutrition FROM obesity o JOIN malnutrition m ON o.gender = m.gender AND o.country = m.country AND o.year = m.year GROUP BY o.gender'''

# %%
cur.execute(query)
result=cur.fetchall()
df=pd.DataFrame(result,columns=[i[0]for i in cur.description])
df
# Out:
#    gender  avg_obesity  avg_malnutrition
# 0    Male    12.776696          6.026317
# 1    Both    12.781970          5.361553
# 2  Female    12.724456          4.675483

# %%
#3.
query = '''SELECT o.region, AVG(o.mean_estimate) AS avg_obesity, AVG(m.mean_estimate) AS avg_malnutrition FROM obesity o JOIN malnutrition m ON o.region = m.region AND o.country = m.country WHERE o.region IN ('Africa', 'America') GROUP BY o.region'''

# %%
cur.execute(query)
result=cur.fetchall()
df=pd.DataFrame(result,columns=[i[0]for i in cur.description])
df
# Out:
#    region  avg_obesity  avg_malnutrition
# 0  Africa     5.415204          8.502186

# %%
#4.
query = '''SELECT o.country, MAX(o.mean_estimate) - MIN(o.mean_estimate) AS obesity_increase, MIN(m.mean_estimate) - MAX(m.mean_estimate) AS malnutrition_decrease FROM obesity o JOIN malnutrition m ON o.country = m.country GROUP BY o.country HAVING obesity_increase > 0 AND malnutrition_decrease > 0 '''

# %%
cur.execute(query)
result=cur.fetchall()
df=pd.DataFrame(result,columns=[i[0]for i in cur.description])
df
# Out:
# Empty DataFrame
# Columns: [country, obesity_increase, malnutrition_decrease]
# Index: []

# %%
#5.
query = '''SELECT o.age_group, AVG(o.mean_estimate) AS avg_obesity, AVG(m.mean_estimate) AS avg_malnutrition FROM obesity o JOIN malnutrition m ON o.age_group = m.age_group AND o.country = m.country GROUP BY o.age_group'''

# %%
cur.execute(query)
result=cur.fetchall()
df=pd.DataFrame(result,columns=[i[0]for i in cur.description])
df
# Out:
#   age_group  avg_obesity  avg_malnutrition
# 0     Adult    21.833224          5.940619
# 1     Child     9.736980          5.159062

# %%
df_obesity.to_json("df_obesity.json", orient="records", lines=True)
df_malnutrition.to_json("df_malnutrition.json", orient="records", lines=True)

# %%
from IPython.display import FileLink, display
display(FileLink("df_obesity.json"))
display(FileLink("df_malnutrition.json"))
# Out:
# C:\Users\alber\Downloads\Feli python prog\project 2\df_obesity.json
# C:\Users\alber\Downloads\Feli python prog\project 2\df_malnutrition.json
